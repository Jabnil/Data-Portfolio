# %% [markdown]
# ## Project 01: E-commerce Sales Analysis Walkthrough

# %% [markdown]
# ### Overview
# I implemented **Jupyter Notebooks** with this project, to showcase how I make use of my previous **Cloud Infrastructure skills** into Data Analysis. In this notebook I use environment isolation with **Docker**, Automation/CI with **GitHub Actions**, **Python** for data cleaning and engineering, **SQL** for business logic and window functions, and **Power BI** for visuals.

# %% [markdown]
# ### 1-Setup the Environment
# Just need to run the following command. It is a script that start the environment with Docker.

# %%
#RUN THE FOLLOWING LINE IN TERMINAL
cd /workspaces/Data-Portfolio/Project-01-Sales-Analysis
/project01_setup.sh

# %% [markdown]
# ### 2-Run the Mock Data Generator Python Script
# This is to generate random raw data that will be our "Dirty" data. This file has random flaws to make it as realistic as posible.

# %%
#run mock data generator code here
cd /workspaces/Data-Portfolio/Project-01-Sales-Analysis
python notebooks/mock_data_generator.py
# Out:
# Traceback (most recent call last):
#   File "/workspaces/Data-Portfolio/Project-01-Sales-Analysis/notebooks/mock_data_generator.py", line 44, in <module>
#     df.to_csv('./data/raw/raw_ecommerce_sales.csv', index=False)
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/util/_decorators.py", line 333, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py", line 3967, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/io/formats/format.py", line 1014, in to_csv
#     csv_formatter.save()
#   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/io/formats/csvs.py", line 251, in save
#     with get_handle(
#          ^^^^^^^^^^^
# ...

# %% [markdown]
# ### 3-The "Before" Snapshot
# Here I have a printscreen of the raw data generated. I filtered the values to showcase the "flaws".

# %%
#image code here

# %% [markdown]
# ### 4-Run the Cleaning Python Script
# This code will remove duplicate rows, filter negative sales and outliers, and organize uncategorized entries.

# %%
#run the data cleaning code here

# %% [markdown]
# ### 5-The "After" Snapshot
# Here I have a printscreen of the cleaned data. I have filtered the values to showcase the "fixes".

# %%
#image code here

# %% [markdown]
# ### 6-Import Cleaned Data Into SQL Database
# This code will import the resulting cleaned data into the SQL database.

# %%
#run the data import code here

# %% [markdown]
# ### 7-Run the SQL Analysis Queries
# There are 3 queries that will run in this order:
# 1. **Identifying Underperforming Categories:** To find categories where the profit margin is below the company average.
# 2. **Year-over-Year (YoY) Growth:** This uses Window Functions to compare sales performance across years.
# 3. **Customer Lifetime Value (CLV):** This identifies "VIP" customers by calculating their total spend and order frequency.

# %%
#run the sql queries code here

# %% [markdown]
# ### 8-Data Visualization
# These are the visual representation of the outputs from the SQL Analysis Queries. Graphics made with both Python and Power BI.

# %%
#Graphics code here

# %% [markdown]
# ### 9-The Final Insight
# Our Analysis revealed the following:
# 1. **Identifying Underperforming Categories:** INSIGHTS HERE
# 2. **Year-over-Year (YoY) Growth:** INSIGHTS HERE
# 3. **Customer Lifetime Value (CLV):** INSIGHTS HERE
